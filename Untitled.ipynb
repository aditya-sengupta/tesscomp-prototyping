# %%
from fit_completeness_to_catalog import *
name = "sullivan"
nwalkers = 24
ndim = 8
# %load_ext autoreload
# %autoreload 2

# %%
catalog, num_stars = get_catalog_and_numstars(name)
synth = make_synth_solar_systems(num_stars=num_stars)
hist_synth, hist_catalog = make_hists(synth, catalog)
# Out:
# Selected 415 stars

# %%
ll, p0 = make_mcmc_setup(hist_synth, hist_catalog, nwalkers)
sampler = emcee.EnsembleSampler(nwalkers, ndim, ll)
_ = sampler.run_mcmc(p0, 100, progress="notebook")
sampler.reset()
pos, _, _ = sampler.run_mcmc(p0, 20000, store=True, progress="notebook")
# Out:
# Found least-squares solution: [ 2.76808976e+01 -1.42510552e-02  4.78648560e-06 -3.79029699e-02
#   9.83123437e-04 -2.76194660e-02 -9.67928653e-02 -4.85188412e-04]
# Set initial condition
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))

# %%
_ = corner.corner(sampler.flatchain)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
params = np.mean(pos, axis=0)
plot_marginalized_comps(params)

# %%
plot_overall_comps(params, name)
